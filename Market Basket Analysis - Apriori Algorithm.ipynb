# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
#!pip install mlxtend
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read Data

# %%
df = pd.read_csv("SALESDATASET.csv")
df.head()
# Out:
#    order_id  status_so status_fo_leading   order_time  code_item  \
# 0     43155  FULFILLED            PACKED  4/7/22 0:02          1
# 1     43155  FULFILLED            PACKED  4/7/22 0:02          2
# 2     43156  FULFILLED            PACKED  4/7/22 0:05          3
# 3     43156  FULFILLED            PACKED  4/7/22 0:05          4
# 4     43157  FULFILLED            PACKED  4/7/22 0:17          5
#
#             item_descr  quantity  selling_price  total_amount
# 0      Toothbrush Soft       1.0           5.61          5.61
# 1  Day Care Toothbrush       1.0           3.14          3.14
# 2    Denture Container       1.0           0.00          0.00
# 3      Denture Cleaner       4.0          45.90        183.60
# 4        Fruit Pestels       2.0          10.08         20.16

# %% [markdown]
# # Overview of Data

# %%
df.shape
# Out:
# (3868, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3868 entries, 0 to 3867
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_id           3868 non-null   int64
#  1   status_so          3868 non-null   object
#  2   status_fo_leading  3866 non-null   object
#  3   order_time         3868 non-null   object
#  4   code_item          3868 non-null   int64
#  5   item_descr         3868 non-null   object
#  6   quantity           3844 non-null   float64
#  7   selling_price      3868 non-null   float64
#  8   total_amount       3868 non-null   float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 272.1+ KB

# %%
df.describe()
# Out:
#            order_id    code_item     quantity  selling_price  total_amount
# count   3868.000000  3868.000000  3844.000000    3868.000000   3868.000000
# mean   44335.936143    38.548087     3.275234      28.748214    127.447479
# std      702.061860    27.404894     3.616569      39.752989    306.473322
# min    42959.000000     1.000000     1.000000       0.000000      0.000000
# 25%    43752.750000    15.000000     1.000000       4.587500      6.202500
# 50%    44295.500000    31.000000     2.000000      17.000000     37.160000
# 75%    44926.000000    63.000000     4.000000      37.050000    164.160000
# max    45611.000000   109.000000    48.000000     627.520000   8232.000000

# %% [markdown]
# # Data Pre-Processing

# %% [markdown]
# ## Handling missing values

# %%
#find null columns with null values
df.isnull().sum()
# Out:
# order_id              0
# status_so             0
# status_fo_leading     2
# order_time            0
# code_item             0
# item_descr            0
# quantity             24
# selling_price         0
# total_amount          0
# dtype: int64

# %%
#get rows with missing value in quantity
missing_qty_rows = df[df['quantity'].isnull()==True].index

# %%
#get quantity by using total amount/ selling price
for i in missing_qty_rows:
    df['quantity'][i] = df['total_amount'][i]/df['selling_price'][i]

# %%
#check if quantity filled
df.iloc[missing_qty_rows]
# Out:
#       order_id  status_so status_fo_leading     order_time  code_item  \
# 732      43612     CANCEL            CANCEL    7/7/22 1:13          9
# 733      43612     CANCEL            CANCEL    7/7/22 1:13          7
# 1097     43839     CANCEL            CANCEL   7/7/22 11:00         73
# 1098     43839     CANCEL            CANCEL   7/7/22 11:00         51
# 1099     43839     CANCEL            CANCEL   7/7/22 11:00         50
# 1103     43838     CANCEL            CANCEL   7/7/22 11:01         73
# 1104     43838     CANCEL            CANCEL   7/7/22 11:01         50
# 1105     43838     CANCEL            CANCEL   7/7/22 11:01         51
# 1316     43947  FULFILLED            PACKED   7/7/22 14:38         13
# 1382     43994      CLOSE            CANCEL   7/7/22 15:59         71
# 1383     43994      CLOSE            CANCEL   7/7/22 15:59         72
# 1504     44066  FULFILLED            PACKED   7/7/22 18:55         28
# 1699     44173  FULFILLED            PACKED   7/7/22 22:09         54
# 1750     44207     CANCEL            CANCEL   7/7/22 22:46         73
# 1751     44207     CANCEL            CANCEL   7/7/22 22:46         46
# 1752     44207     CANCEL            CANCEL   7/7/22 22:46          5
# 1753     44207     CANCEL            CANCEL   7/7/22 22:46         31
# 1754     44207     CANCEL            CANCEL   7/7/22 22:46         15
# 1756     44208  FULFILLED            PACKED   7/7/22 22:46         12
# 2070     44376     CANCEL            CANCEL   9/7/22 12:51         41
# 2071     44376     CANCEL            CANCEL   9/7/22 12:51         27
# 2239     44484     CANCEL            CANCEL  10/7/22 20:08         14
# 2291     44521     CANCEL               NaN  11/7/22 13:32         33
# 2292     44521     CANCEL               NaN  11/7/22 13:32         12
#
#                                      item_descr  quantity  selling_price  \
# 732                               Vitamin Water      24.0          26.67
# 733                                Stationeries       NaN           0.00
# 1097       Vitamin Gummies (Multi Flavour) 200g       NaN           0.00
# 1098  Vitamin Gummies (Blackberry Flavour) 100g       2.0          27.00
# 1099      Vitamin Gummies (Orange Flavour) 100g       NaN           0.00
# 1103       Vitamin Gummies (Multi Flavour) 200g       NaN           0.00
# 1104      Vitamin Gummies (Orange Flavour) 100g       NaN           0.00
# 1105  Vitamin Gummies (Blackberry Flavour) 100g       2.0          27.00
# 1316                Kids Teeth ToothPaste 55ml        1.0           6.78
# 1382                      Fresh Mint Toothpaste       1.0          13.60
# 1383                     Travel Pack Toothpaste       NaN           0.00
# 1504                               Sinus Tablet       1.0          10.50
# 1699                        Joint Health Tablet       1.0          76.70
# 1750       Vitamin Gummies (Multi Flavour) 200g       4.0           9.10
# 1751               Sensitive and Gum Toothbrush       3.0           9.20
# 1752                              Fruit Pestels       2.0           7.63
# 1753       Vitamin Gummies (Berry Flavour) 100g       2.0           9.10
# 1754                       Vitamin Water Orange       2.0           9.28
# 1756                          Repair Toothpaste       1.0           6.38
# 2070                                   Backpack       NaN           0.00
# 2071                          Paracetomol 500mg       4.0          15.00
# 2239                      Vitamin Tablets 100mg       1.0          73.93
# 2291                      Deep Clean Toothpaste      12.0          12.75
# 2292                          Repair Toothpaste       6.0          26.61
#
#       total_amount
# 732         640.08
# 733           0.00
# 1097          0.00
# 1098         54.00
# 1099          0.00
# 1103          0.00
# 1104          0.00
# 1105         54.00
# 1316          6.78
# 1382         13.60
# 1383          0.00
# 1504         10.50
# 1699         76.70
# 1750         36.40
# 1751         27.60
# 1752         15.26
# 1753         18.20
# 1754         18.56
# 1756          6.38
# 2070          0.00
# 2071         60.00
# 2239         73.93
# 2291        153.00
# 2292        159.66

# %%
#remaining empty quantities
df[df['quantity'].isnull()==True]
# Out:
#       order_id status_so status_fo_leading    order_time  code_item  \
# 733      43612    CANCEL            CANCEL   7/7/22 1:13          7
# 1097     43839    CANCEL            CANCEL  7/7/22 11:00         73
# 1099     43839    CANCEL            CANCEL  7/7/22 11:00         50
# 1103     43838    CANCEL            CANCEL  7/7/22 11:01         73
# 1104     43838    CANCEL            CANCEL  7/7/22 11:01         50
# 1383     43994     CLOSE            CANCEL  7/7/22 15:59         72
# 2070     44376    CANCEL            CANCEL  9/7/22 12:51         41
#
#                                  item_descr  quantity  selling_price  \
# 733                            Stationeries       NaN            0.0
# 1097   Vitamin Gummies (Multi Flavour) 200g       NaN            0.0
# 1099  Vitamin Gummies (Orange Flavour) 100g       NaN            0.0
# 1103   Vitamin Gummies (Multi Flavour) 200g       NaN            0.0
# 1104  Vitamin Gummies (Orange Flavour) 100g       NaN            0.0
# 1383                 Travel Pack Toothpaste       NaN            0.0
# 2070                               Backpack       NaN            0.0
#
#       total_amount
# 733            0.0
# 1097           0.0
# 1099           0.0
# 1103           0.0
# 1104           0.0
# 1383           0.0
# 2070           0.0

# %%
#drop rows where quantity is nan
df = df.dropna(subset= ['quantity'])

# %%
#get rows with missing values in status fo leading column
missing_status_rows = df[df['status_fo_leading'].isnull()==True].index

# %%
#replace na values with 'CANCEL'
for i in missing_qty_rows:
    df['status_fo_leading'][i] = 'CANCEL'

# %%
#check for any other missing values
df.isnull().sum()
# Out:
# order_id             0
# status_so            0
# status_fo_leading    0
# order_time           0
# code_item            0
# item_descr           0
# quantity             0
# selling_price        0
# total_amount         0
# dtype: int64

# %% [markdown]
# ## Data Types

# %%
#check data types for each column
df.dtypes
# Out:
# order_id               int64
# status_so             object
# status_fo_leading     object
# order_time            object
# code_item              int64
# item_descr            object
# quantity             float64
# selling_price        float64
# total_amount         float64
# dtype: object

# %%
#convert order_id to string
df.order_id = df.order_id.astype(str)

#convert order-time to datetime
df.order_time = pd.to_datetime(df.order_time)

#convert quantity to interger
df.quantity = df.quantity.astype(int)

df.dtypes
# Out:
# order_id                     object
# status_so                    object
# status_fo_leading            object
# order_time           datetime64[ns]
# code_item                     int64
# item_descr                   object
# quantity                      int64
# selling_price               float64
# total_amount                float64
# dtype: object

# %% [markdown]
# ## Remove freebies (Stationaries, Pen, Skillet and Backpack)

# %%
remove = ['Pen', 'Stationeries', 'Backpack', 'Skillet']

for item in remove:
    df = df[df['item_descr'] != item]

# %% [markdown]
# # Format table for Apriori Analysis

# %%
#reformat df for apriori analysis
#group by order id and item description
#sum quantity
#pivot column labels
#reset index
#fill nan values w 0
#set orderid as index
basket = df.groupby(['order_id','item_descr'])['quantity'].sum().unstack().reset_index().fillna(0).set_index('order_id')

# %%
basket.head()
# Out:
# item_descr  14 Day Whitening Toothpaste  Abrasion Cream  All Round Toothpaste  \
# order_id
# 42959                               0.0             0.0                   0.0
# 42977                               0.0             0.0                   0.0
# 43005                               0.0             0.0                   0.0
# 43012                               0.0             0.0                   0.0
# 43013                               0.0             0.0                   0.0
#
# item_descr  Boroca  Boroca (50)  Calcium Flavoured Tablet (60)  \
# order_id
# 42959          0.0          0.0                            0.0
# 42977          0.0          0.0                            0.0
# 43005          0.0          0.0                            0.0
# 43012          0.0          0.0                            0.0
# 43013          0.0          0.0                            0.0
#
# item_descr  Calcium Tablet (100)  Calcium Tablet (200)  Calcium Tablet (30)  \
# order_id
# 42959                        0.0                   0.0                  0.0
# 42977                        0.0                   0.0                  0.0
# 43005                        0.0                   0.0                  0.0
# 43012                        0.0                   0.0                  0.0
# 43013                        0.0                   0.0                  0.0
#
# item_descr  Calcium Tablet (500)  ...  \
# order_id                          ...
# 42959                        0.0  ...
# 42977                        0.0  ...
# 43005                        0.0  ...
# 43012                        0.0  ...
# 43013                        0.0  ...
#
# item_descr  Vitamin Gummies (Strawberry Flavour) 200g  \
# order_id
# 42959                                             0.0
# 42977                                             0.0
# 43005                                             0.0
# 43012                                             0.0
# 43013                                             0.0
#
# item_descr  Vitamin Gummies (Watermelon Flavour) 100g  \
# order_id
# 42959                                             0.0
# 42977                                             0.0
# 43005                                             0.0
# 43012                                             0.0
# 43013                                             0.0
#
# item_descr  Vitamin Gummies (Watermelon Flavour) 50g  Vitamin Tablets 100mg  \
# order_id
# 42959                                            0.0                    0.0
# 42977                                            0.0                    0.0
# 43005                                            0.0                    0.0
# 43012                                            0.0                    0.0
# 43013                                            0.0                    0.0
#
# item_descr  Vitamin Water  Vitamin Water Orange  Whitening Toothpaste  \
# order_id
# 42959                 0.0                   0.0                   0.0
# 42977                 4.0                   0.0                   0.0
# 43005                 0.0                   0.0                   0.0
# 43012                 0.0                   0.0                   0.0
# 43013                 0.0                   0.0                   0.0
#
# item_descr  XTRA Fresh Toothpaste  XTRA Mint Toothpaste  \
# order_id
# 42959                         0.0                   0.0
# 42977                         0.0                   0.0
# 43005                         0.0                   0.0
# 43012                         0.0                   0.0
# 43013                         0.0                   0.0
#
# item_descr  XTRA Whitening Toothpaste
# order_id
# 42959                             0.0
# 42977                             0.0
# 43005                             0.0
# 43012                             0.0
# 43013                             0.0
#
# [5 rows x 104 columns]

# %%
#function to change quantities to occurences 
#as the association analysis considers itemsets 
def encode_values(x):
    if x <= 0:
        return 0
    elif x >= 1:
        return 1

# %%
#apply encode values function to every element of basket 
basket_encoded = basket.applymap(encode_values)
basket_encoded.head()
# Out:
# item_descr  14 Day Whitening Toothpaste  Abrasion Cream  All Round Toothpaste  \
# order_id
# 42959                                 0               0                     0
# 42977                                 0               0                     0
# 43005                                 0               0                     0
# 43012                                 0               0                     0
# 43013                                 0               0                     0
#
# item_descr  Boroca  Boroca (50)  Calcium Flavoured Tablet (60)  \
# order_id
# 42959            0            0                              0
# 42977            0            0                              0
# 43005            0            0                              0
# 43012            0            0                              0
# 43013            0            0                              0
#
# item_descr  Calcium Tablet (100)  Calcium Tablet (200)  Calcium Tablet (30)  \
# order_id
# 42959                          0                     0                    0
# 42977                          0                     0                    0
# 43005                          0                     0                    0
# 43012                          0                     0                    0
# 43013                          0                     0                    0
#
# item_descr  Calcium Tablet (500)  ...  \
# order_id                          ...
# 42959                          0  ...
# 42977                          0  ...
# 43005                          0  ...
# 43012                          0  ...
# 43013                          0  ...
#
# item_descr  Vitamin Gummies (Strawberry Flavour) 200g  \
# order_id
# 42959                                               0
# 42977                                               0
# 43005                                               0
# 43012                                               0
# 43013                                               0
#
# item_descr  Vitamin Gummies (Watermelon Flavour) 100g  \
# order_id
# 42959                                               0
# 42977                                               0
# 43005                                               0
# 43012                                               0
# 43013                                               0
#
# item_descr  Vitamin Gummies (Watermelon Flavour) 50g  Vitamin Tablets 100mg  \
# order_id
# 42959                                              0                      0
# 42977                                              0                      0
# 43005                                              0                      0
# 43012                                              0                      0
# 43013                                              0                      0
#
# item_descr  Vitamin Water  Vitamin Water Orange  Whitening Toothpaste  \
# order_id
# 42959                   0                     0                     0
# 42977                   1                     0                     0
# 43005                   0                     0                     0
# 43012                   0                     0                     0
# 43013                   0                     0                     0
#
# item_descr  XTRA Fresh Toothpaste  XTRA Mint Toothpaste  \
# order_id
# 42959                           0                     0
# 42977                           0                     0
# 43005                           0                     0
# 43012                           0                     0
# 43013                           0                     0
#
# item_descr  XTRA Whitening Toothpaste
# order_id
# 42959                               0
# 42977                               0
# 43005                               0
# 43012                               0
# 43013                               0
#
# [5 rows x 104 columns]

# %% [markdown]
# # Top 5 Items

# %%
top_df = df.groupby('item_descr').sum()
top_df = top_df.sort_values(by = 'quantity', ascending = False)
top_df.head()
# Out:
#                       code_item  quantity  selling_price  total_amount
# item_descr
# Vitamin Water Orange       2595       857        4515.17      27261.01
# Rash Cream                  522       778        2803.03      33672.26
# Repair Toothpaste          1056       607        2428.27      19932.35
# Retainer Cleaner           3600       584        3357.18      18380.04
# Toothbrush 3 pack          2520       506        2384.11      18652.31

# %% [markdown]
# # Training Model

# %%
frequent_itemsets = apriori(basket_encoded, min_support= 0.01, use_colnames=True)

# %%
rules = association_rules(frequent_itemsets, metric='lift', min_threshold=1)

# %%
rules.head()
# Out:
#                                    antecedents  \
# 0                      (Fresh Mint Toothpaste)
# 1                     (Travel Pack Toothpaste)
# 2       (Vitamin Gummies (Multi Flavour) 100g)
# 3  (Vitamin Gummies (Blackberry Flavour) 100g)
# 4       (Vitamin Gummies (Multi Flavour) 200g)
#
#                                    consequents  antecedent support  \
# 0                     (Travel Pack Toothpaste)            0.071275
# 1                      (Fresh Mint Toothpaste)            0.073851
# 2  (Vitamin Gummies (Blackberry Flavour) 100g)            0.038214
# 3       (Vitamin Gummies (Multi Flavour) 100g)            0.043796
# 4  (Vitamin Gummies (Blackberry Flavour) 100g)            0.045942
#
#    consequent support   support  confidence       lift  leverage  conviction
# 0            0.073851  0.067411    0.945783  12.806563  0.062147   17.082296
# 1            0.071275  0.067411    0.912791  12.806563  0.062147   10.649377
# 2            0.043796  0.016745    0.438202  10.005618  0.015072    1.702044
# 3            0.038214  0.016745    0.382353  10.005618  0.015072    1.557178
# 4            0.043796  0.016316    0.355140   8.109034  0.014304    1.482810

# %%
#create new columns to show number of items in antecedent and consequent
rules["antecedent_len"] = rules["antecedents"].apply(lambda x: len(x))
rules["consequents_len"] = rules["consequents"].apply(lambda x: len(x))

# %% [markdown]
# # RESULTS

# %% [markdown]
# ## Single Antecedent

# %%
#setting filters and thresholds
single = rules[ (rules['antecedent_len'] == 1) &
               (rules['consequents_len'] == 1) &
               (rules['confidence'] > 0.5) &
               (rules['lift'] > 1) ]

# %%
print("There are {} Relation derived.".format(len(single)))
# Out:
# There are 8 Relation derived.

# %%
#sort table to show results with highest lift first
single = single.sort_values(by='lift',ascending=False)
single = single.reset_index(drop = True)

# %%
#function to print out all rules and their metrics
def show_rules(dataframe):
    for row in dataframe.index:
        #print itemset
        print("Rule: " + str(dataframe['antecedents'][row])[12:-3] + " -> " + str(dataframe['consequents'][row])[12:-3])

        #print support
        print("Support: " + str(dataframe['support'][row]))

        #print confidence
        print("Confidence: " + str(dataframe['confidence'][row]))

        #print lift
        print("Lift: " + str(dataframe['lift'][row]))
        print("=====================================")

show_rules(single)
# Out:
# Rule: Vitamin Gummies (Blackberry Flavour) 100g -> Vitamin Gummies (Orange Flavour) 100g
# Support: 0.0347788750536711
# Confidence: 0.7941176470588235
# Lift: 21.017045454545453
# =====================================
# Rule: Vitamin Gummies (Orange Flavour) 100g -> Vitamin Gummies (Blackberry Flavour) 100g
# Support: 0.0347788750536711
# Confidence: 0.9204545454545454
# Lift: 21.017045454545453
# =====================================
# Rule: Vitamin Gummies (Strawberry Flavour) 100g -> Vitamin Gummies (Orange Flavour) 100g
# Support: 0.0210390725633319
# Confidence: 0.6363636363636362
# Lift: 16.841942148760328
# =====================================
# Rule: Vitamin Gummies (Orange Flavour) 100g -> Vitamin Gummies (Strawberry Flavour) 100g
# Support: 0.0210390725633319
# Confidence: 0.5568181818181818
# Lift: 16.841942148760328
# =====================================
# Rule: Vitamin Gummies (Strawberry Flavour) 100g -> Vitamin Gummies (Blackberry Flavour) 100g
# Support: 0.0210390725633319
# Confidence: 0.6363636363636362
# Lift: 14.530303030303028
# =====================================
# Rule: Vitamin Gummies (Strawberry Flavour) 100g -> Vitamin Gummies (Multi Flavour) 100g
# Support: 0.016745384285100903
# Confidence: 0.5064935064935066
# Lift: 13.25419524295929
# =====================================
# Rule: Fresh Mint Toothpaste -> Travel Pack Toothpaste
# Support: 0.0674109059682267
# Confidence: 0.9457831325301204
# Lift: 12.806563463154944
# =====================================
# Rule: Travel Pack Toothpaste -> Fresh Mint Toothpaste
# Support: 0.0674109059682267
# Confidence: 0.9127906976744186
# Lift: 12.806563463154944
# =====================================

# %% [markdown]
# ## Double Antecedent

# %%
#setting filters and thresholds
double = rules[ (rules['antecedent_len'] == 2) &
               (rules['consequents_len'] == 1) &
               (rules['confidence'] > 0.75) &
               (rules['lift'] > 1) ]

# %%
print("There are {} Relation derived.".format(len(double)))
# Out:
# There are 12 Relation derived.

# %%
#sort table to show results with highest lift first
double = double.sort_values(by='lift',ascending=False)
double = double.reset_index(drop = True)

# %%
show_rules(double)
# Out:
# Rule: Vitamin Gummies (Multi Flavour) 100g', 'Vitamin Gummies (Blackberry Flavour) 100g -> Vitamin Gummies (Strawberry Flavour) 100g
# Support: 0.016745384285100903
# Confidence: 1.0
# Lift: 30.246753246753244
# =====================================
# Rule: Vitamin Gummies (Multi Flavour) 100g', 'Vitamin Gummies (Orange Flavour) 100g -> Vitamin Gummies (Strawberry Flavour) 100g
# Support: 0.016316015457277802
# Confidence: 0.9500000000000001
# Lift: 28.734415584415583
# =====================================
# Rule: Vitamin Gummies (Multi Flavour) 100g', 'Vitamin Gummies (Blackberry Flavour) 100g -> Vitamin Gummies (Orange Flavour) 100g
# Support: 0.016316015457277802
# Confidence: 0.9743589743589743
# Lift: 25.787296037296038
# =====================================
# Rule: Vitamin Gummies (Strawberry Flavour) 100g', 'Vitamin Gummies (Multi Flavour) 100g -> Vitamin Gummies (Orange Flavour) 100g
# Support: 0.016316015457277802
# Confidence: 0.9743589743589743
# Lift: 25.787296037296038
# =====================================
# Rule: Vitamin Gummies (Strawberry Flavour) 100g', 'Vitamin Gummies (Blackberry Flavour) 100g -> Vitamin Gummies (Orange Flavour) 100g
# Support: 0.020180334907685702
# Confidence: 0.9591836734693878
# Lift: 25.385667903525047
# =====================================
# Rule: Vitamin Gummies (Multi Flavour) 200g', 'Vitamin Gummies (Blackberry Flavour) 100g -> Vitamin Gummies (Orange Flavour) 100g
# Support: 0.015457277801631602
# Confidence: 0.9473684210526315
# Lift: 25.072966507177032
# =====================================
# Rule: Vitamin Gummies (Strawberry Flavour) 100g', 'Vitamin Gummies (Multi Flavour) 100g -> Vitamin Gummies (Blackberry Flavour) 100g
# Support: 0.016745384285100903
# Confidence: 1.0
# Lift: 22.833333333333332
# =====================================
# Rule: Vitamin Gummies (Strawberry Flavour) 100g', 'Vitamin Gummies (Orange Flavour) 100g -> Vitamin Gummies (Blackberry Flavour) 100g
# Support: 0.020180334907685702
# Confidence: 0.9591836734693878
# Lift: 21.901360544217688
# =====================================
# Rule: Vitamin Gummies (Multi Flavour) 100g', 'Vitamin Gummies (Orange Flavour) 100g -> Vitamin Gummies (Blackberry Flavour) 100g
# Support: 0.016316015457277802
# Confidence: 0.9500000000000001
# Lift: 21.691666666666666
# =====================================
# Rule: Vitamin Gummies (Multi Flavour) 200g', 'Vitamin Gummies (Orange Flavour) 100g -> Vitamin Gummies (Blackberry Flavour) 100g
# Support: 0.015457277801631602
# Confidence: 0.9473684210526315
# Lift: 21.631578947368418
# =====================================
# Rule: Vitamin Gummies (Strawberry Flavour) 100g', 'Vitamin Gummies (Blackberry Flavour) 100g -> Vitamin Gummies (Multi Flavour) 100g
# Support: 0.016745384285100903
# Confidence: 0.7959183673469389
# Lift: 20.82802109607888
# =====================================
# Rule: Vitamin Gummies (Strawberry Flavour) 100g', 'Vitamin Gummies (Orange Flavour) 100g -> Vitamin Gummies (Multi Flavour) 100g
# Support: 0.016316015457277802
# Confidence: 0.7755102040816327
# Lift: 20.2939692731025
# =====================================

# %% [markdown]
# # Recommendations

# %% [markdown]
# The results of the Apriori Analysis have uncovered several insights regarding association between products. With these results, our recommendations are as follows:
#
# Firstly, Vitamin Gummies of size 100g of any flavour can be bundled together in 2s and 3s at a slightly discounted rate to increase sales. Alternatively, the company can target users who purchase 1 bottle of vitamin gummies and upsell them additional bottles before check out under the "people who buy this also buy this" section.
#
# Our reasoning for this due to the strong likelihood that Vitamin Gummies are purchased together. This is evident from the Lift metric for all results with Vitamin Gummies. As the Lift metric for all these results are greater than 1, it indicates that the second item is likely to be bought if the first item is bought. Therefore, we would strongly recommend this strategy to increase the basket size and sales revenue.
#
# Secondly, we would recommend bundling Fresh Mint Toothpaste and Travel Pack Toothpaste together.
#
# Our reasoning for this is also due to the strong relationship between these 2 products. From the results, we can see that the Lift metric for these 2 items is 12 which is much greater than 1, indicating that item 2 is very likely to be bought if item 1 is bought. Hence, we would recommend bundling these 2 items together at an attractive price to potentially increase basket size.
